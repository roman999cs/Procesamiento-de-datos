# %% [markdown]
# <div style="border:2px solid #2c3e50; padding:14px; border-radius:8px; font-family:sans-serif;">
# <h3 style="margin-top:0;">📌 Membrete de identificación</h3>
# <ul>
# <li><b>Estudiante:</b> Sebastián Gómez Román</li>
# <li><b>Código:</b> 20570444</li>
# <li><b>Curso:</b> Procesamiento de Datos a Gran Escala</li>
# <li><b>Profesor:</b> John Corredor Franco</li>
# </ul>
# </div>

# %% [markdown]
# <h1>Procesamiento de Datos a Gran Escala — Edición Fútbol</h1>

# %% [markdown]
# <h2>Listas en Python</h2>

# %% [markdown]
# <p>Este es el cuaderno 3, en este cuaderno veremos listas en Python, todo esto de una manera breve y sencilla, a lo largo de este cuaderno podrás ver temas como indexación, operaciones con listas, y copiado y clonación de listas.</p>

# %% [markdown]
# <h2>Tabla de Contenido</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#dataset">Acerca de los conjuntos de datos (Dataset)</a>
#         </li>
#         <li>
#             <a href="#listas">Listas</a>
#         </li>
#         <li>
#             <a href="#index">Indexación</a>
#         </li>
#         <li>
#             <a href="#content">Contenido de la Lista</a>
#         </li>
#         <li>
#             <a href="#ops">Operaciones con Listas</a>
#         </li>
#         <li>
#             <a href="#copy">Copiado y Clonación de Listas</a>
#         </li>
#         <li>
#             <a href="#quiz">Exámen sobre Listas</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 id="dataset">Acerca de los conjuntos de datos (Dataset)</h2>

# %% [markdown]
# Vamos a trabajar con la nómina de un equipo de fútbol: nombres de jugadores, dorsales y posiciones.

# %% [markdown]
# <h2 id="listas">Listas</h2>

# %% [markdown]
# Una lista es una secuencia ordenada y <b>mutable</b> de elementos, definida entre corchetes <code>[]</code>.

# %%
Plantilla = ['Ospina', 'Cuadrado', 'Muñoz', 'Lerma', 'Díaz']
Plantilla
# Out:
# ['Ospina', 'Cuadrado', 'Muñoz', 'Lerma', 'Díaz']

# %% [markdown]
# Una lista puede mezclar distintos tipos de datos:

# %%
Jugador = ['James Rodríguez', 10, 1.80, 'Volante']
Jugador
# Out:
# ['James Rodríguez', 10, 1.8, 'Volante']

# %% [markdown]
# Las listas pueden estar anidadas, por ejemplo una lista de listas con varios jugadores:

# %%
Nomina = [['Ospina', 1, 'Portero'], ['Cuadrado', 15, 'Defensa'], ['Díaz', 7, 'Delantero']]
Nomina
# Out:
# [['Ospina', 1, 'Portero'],
#  ['Cuadrado', 15, 'Defensa'],
#  ['Díaz', 7, 'Delantero']]

# %% [markdown]
# <h2 id="index">Indexación</h2>

# %% [markdown]
# Al igual que con las cadenas y tuplas, cada elemento tiene un índice, empezando en 0.

# %%
Plantilla[0]
# Out:
# 'Ospina'

# %%
Plantilla[-1]
# Out:
# 'Díaz'

# %% [markdown]
# Podemos usar slicing para obtener varios elementos:

# %%
Plantilla[1:3]
# Out:
# ['Cuadrado', 'Muñoz']

# %% [markdown]
# <h2 id="content">Contenido de la Lista</h2>

# %% [markdown]
# A diferencia de las tuplas, las listas son <b>mutables</b>: podemos cambiar sus elementos.

# %%
Plantilla[0] = 'Vargas'
Plantilla
# Out:
# ['Vargas', 'Cuadrado', 'Muñoz', 'Lerma', 'Díaz']

# %% [markdown]
# Podemos concatenar listas con <code>+</code>, por ejemplo para sumar refuerzos a la plantilla:

# %%
Refuerzos = ['Borré', 'Zapata']
Plantilla + Refuerzos
# Out:
# ['Vargas', 'Cuadrado', 'Muñoz', 'Lerma', 'Díaz', 'Borré', 'Zapata']

# %% [markdown]
# <h2 id="ops">Operaciones con Listas</h2>

# %% [markdown]
# El método <code>append()</code> agrega un elemento al final de la lista:

# %%
Goleadores = ['Falcao', 'Muriel']
Goleadores.append('Zapata')
Goleadores
# Out:
# ['Falcao', 'Muriel', 'Zapata']

# %% [markdown]
# El método <code>extend()</code> agrega varios elementos de otra lista:

# %%
Goleadores.extend(['Borré', 'Díaz'])
Goleadores
# Out:
# ['Falcao', 'Muriel', 'Zapata', 'Borré', 'Díaz']

# %% [markdown]
# El método <code>del</code> elimina un elemento dado su índice:

# %%
del(Goleadores[0])
Goleadores
# Out:
# ['Muriel', 'Zapata', 'Borré', 'Díaz']

# %% [markdown]
# Podemos convertir una cadena separada por comas en una lista con <code>split()</code>, por ejemplo la alineación titular:

# %%
Titulares = 'Ospina,Cuadrado,Muñoz,Lerma,Díaz'
Titulares.split(',')
# Out:
# ['Ospina', 'Cuadrado', 'Muñoz', 'Lerma', 'Díaz']

# %% [markdown]
# <h2 id="copy">Copiado y Clonación de Listas</h2>

# %% [markdown]
# Si asignamos una lista a una nueva variable con <code>=</code>, ambas variables apuntan a la <b>misma</b> lista en memoria.

# %%
EquipoA = ['Ospina', 'Cuadrado', 'Muñoz']
EquipoB = EquipoA
EquipoB[0] = 'Vargas'
EquipoA
# Out:
# ['Vargas', 'Cuadrado', 'Muñoz']

# %% [markdown]
# Para clonar una lista de verdad (una copia independiente), usamos slicing completo <code>[:]</code>:

# %%
EquipoC = EquipoA[:]
EquipoC[0] = 'Otro Portero'
print('EquipoA:', EquipoA)
print('EquipoC:', EquipoC)
# Out:
# EquipoA: ['Vargas', 'Cuadrado', 'Muñoz']
# EquipoC: ['Otro Portero', 'Cuadrado', 'Muñoz']

# %% [markdown]
# <h2 id="quiz">Exámen sobre Listas</h2>

# %% [markdown]
# Crea una lista llamada <code>Delanteros</code> con tres nombres de delanteros.

# %%
Delanteros = ["Falcao", "Muriel", "Zapata"]
Delanteros
# Out:
# ['Falcao', 'Muriel', 'Zapata']

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Delanteros = ["Falcao", "Muriel", "Zapata"]
# Delanteros
# -->

# %% [markdown]
# Agrega el jugador <code>'Borré'</code> al final de la lista <code>Delanteros</code> usando <code>append()</code>.

# %%
Delanteros.append("Borré")
Delanteros
# Out:
# ['Falcao', 'Muriel', 'Zapata', 'Borré']

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Delanteros.append("Borré")
# Delanteros
# -->

# %% [markdown]
# Dada la lista <code>Calendario</code>, usa slicing para obtener los partidos de la posición 2 en adelante.

# %%
Calendario = ['vs Nacional', 'vs Junior', 'vs América', 'vs Millonarios']
Calendario[2:]
# Out:
# ['vs América', 'vs Millonarios']

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Calendario[2:]
# -->

# %% [markdown]
# <h2>Conclusión</h2>
# <p>En este cuaderno aprendí que las listas sí son mutables, y practiqué cómo indexarlas, modificarlas, agregarles o quitarles jugadores, y la diferencia entre copiar y clonar una lista.</p>
