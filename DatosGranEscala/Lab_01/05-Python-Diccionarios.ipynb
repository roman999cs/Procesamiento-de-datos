# %% [markdown]
# <div style="border:2px solid #2c3e50; padding:14px; border-radius:8px; font-family:sans-serif;">
# <h3 style="margin-top:0;">📌 Membrete de identificación</h3>
# <ul>
# <li><b>Estudiante:</b> Sebastián Gómez Román</li>
# <li><b>Código:</b> 20570444</li>
# <li><b>Curso:</b> Procesamiento de Datos a Gran Escala</li>
# <li><b>Profesor:</b> John Corredor Franco</li>
# </ul>
# </div>

# %% [markdown]
# <h1>Procesamiento de Datos a Gran Escala — Edición Fútbol</h1>

# %% [markdown]
# <h2>Diccionarios en Python</h2>

# %% [markdown]
# <p>Este es el cuaderno 5, en este cuaderno veremos diccionarios en Python, todo esto de una manera breve y sencilla, a lo largo de este cuaderno podrás ver temas como las llaves y valores de un diccionario, y cómo agregar o eliminar datos.</p>

# %% [markdown]
# <h2>Tabla de Contenido</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="#dicc">Diccionarios</a>
#         </li>
#         <li>
#             <a href="#que-son">¿Qué son los diccionarios?</a>
#         </li>
#         <li>
#             <a href="#llaves">Llaves</a>
#         </li>
#         <li>
#             <a href="#quiz">Cuestionario sobre Diccionarios</a>
#         </li>
#     </ul>
# </div>

# %% [markdown]
# <h2 id="dicc">Diccionarios</h2>

# %% [markdown]
# Un diccionario almacena datos en pares <b>llave: valor</b>, entre llaves <code>{}</code>.

# %%
Jugador = {'Nombre': 'James Rodríguez', 'Dorsal': 10, 'Posición': 'Volante', 'Goles': 5}
Jugador
# Out:
# {'Nombre': 'James Rodríguez', 'Dorsal': 10, 'Posición': 'Volante', 'Goles': 5}

# %% [markdown]
# <h2 id="que-son">¿Qué son los diccionarios?</h2>

# %% [markdown]
# A diferencia de las listas, en un diccionario accedemos a los valores usando su <b>llave</b>, no un índice numérico.

# %%
Jugador['Nombre']
# Out:
# 'James Rodríguez'

# %%
Jugador['Goles']
# Out:
# 5

# %% [markdown]
# Un diccionario también puede tener listas o incluso otros diccionarios como valores, por ejemplo el historial de resultados de un equipo:

# %%
Equipo = {'Nombre': 'Nacional', 'Resultados': ['G', 'E', 'G', 'P'], 'DT': 'Un técnico'}
Equipo['Resultados']
# Out:
# ['G', 'E', 'G', 'P']

# %% [markdown]
# <h2 id="llaves">Llaves</h2>

# %% [markdown]
# Podemos obtener todas las llaves de un diccionario con <code>keys()</code>:

# %%
Jugador.keys()
# Out:
# dict_keys(['Nombre', 'Dorsal', 'Posición', 'Goles'])

# %% [markdown]
# Y todos los valores con <code>values()</code>:

# %%
Jugador.values()
# Out:
# dict_values(['James Rodríguez', 10, 'Volante', 5])

# %% [markdown]
# Para agregar un nuevo par llave-valor, simplemente asignamos un valor a una llave nueva:

# %%
Jugador['Asistencias'] = 3
Jugador
# Out:
# {'Nombre': 'James Rodríguez',
#  'Dorsal': 10,
#  'Posición': 'Volante',
#  'Goles': 5,
#  'Asistencias': 3}

# %% [markdown]
# Para eliminar una llave, usamos <code>del</code>:

# %%
del(Jugador['Asistencias'])
Jugador
# Out:
# {'Nombre': 'James Rodríguez', 'Dorsal': 10, 'Posición': 'Volante', 'Goles': 5}

# %% [markdown]
# Con <code>in</code> podemos verificar si una llave existe en el diccionario:

# %%
'Dorsal' in Jugador
# Out:
# True

# %% [markdown]
# <h2 id="quiz">Cuestionario sobre Diccionarios</h2>

# %% [markdown]
# Crea un diccionario llamado <code>Marcador</code> con las llaves <code>'Local'</code>, <code>'Visitante'</code>, <code>'GolesLocal'</code> y <code>'GolesVisitante'</code>.

# %%
Marcador = {"Local": "Millonarios", "Visitante": "Nacional", "GolesLocal": 2, "GolesVisitante": 1}
Marcador
# Out:
# {'Local': 'Millonarios',
#  'Visitante': 'Nacional',
#  'GolesLocal': 2,
#  'GolesVisitante': 1}

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Marcador = {"Local": "Millonarios", "Visitante": "Nacional", "GolesLocal": 2, "GolesVisitante": 1}
# Marcador
# -->

# %% [markdown]
# Usando el diccionario <code>Marcador</code>, obtén el valor de <code>'GolesLocal'</code>.

# %%
Marcador["GolesLocal"]
# Out:
# 2

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Marcador["GolesLocal"]
# -->

# %% [markdown]
# Obtén todas las llaves del diccionario <code>Marcador</code>.

# %%
Marcador.keys()
# Out:
# dict_keys(['Local', 'Visitante', 'GolesLocal', 'GolesVisitante'])

# %% [markdown]
# Haz doble click <b>aquí</b> para ver la solución.
# <!-- Tu respuesta:
# Marcador.keys()
# -->

# %% [markdown]
# <h2>Conclusión</h2>
# <p>En este cuaderno entendí que los diccionarios son ideales para guardar información relacionada de un jugador o un partido, y practiqué cómo crear, leer, agregar y eliminar datos usando llaves.</p>
